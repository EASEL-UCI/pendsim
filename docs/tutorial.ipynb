# %% [markdown]
# # Tutorial

# %%
# !pip install git+https://github.com/easel-uci/pendsim.git
from pendsim import sim, controller, viz
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting git+https://github.com/easel-uci/pendsim.git
#   Cloning https://github.com/easel-uci/pendsim.git to /private/var/folders/k0/b23vl_1x1rj9rdyyydnn0xt40000gn/T/pip-req-build-57frlasc
#   Running command git clone --filter=blob:none --quiet https://github.com/easel-uci/pendsim.git /private/var/folders/k0/b23vl_1x1rj9rdyyydnn0xt40000gn/T/pip-req-build-57frlasc
#   Resolved https://github.com/easel-uci/pendsim.git to commit 04137adfdfa757db5b3d6ee0f10e2aaafa8ec264
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filterpy in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pendsim==1.0.4) (1.4.5)
# Requirement already satisfied: scipy in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pendsim==1.0.4) (1.9.1)
# Requirement already satisfied: pandas in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pendsim==1.0.4) (1.4.4)
# Requirement already satisfied: six in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pendsim==1.0.4) (1.16.0)
# Requirement already satisfied: tqdm in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pendsim==1.0.4) (4.64.1)
# Requirement already satisfied: pytest in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pendsim==1.0.4) (7.1.2)
# Requirement already satisfied: matplotlib in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pendsim==1.0.4) (3.5.2)
# Requirement already satisfied: scikit-learn in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pendsim==1.0.4) (1.0.2)
# Requirement already satisfied: numpy in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pendsim==1.0.4) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pendsim==1.0.4) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pendsim==1.0.4) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pendsim==1.0.4) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pendsim==1.0.4) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pendsim==1.0.4) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pendsim==1.0.4) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pendsim==1.0.4) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pandas->pendsim==1.0.4) (2022.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pytest->pendsim==1.0.4) (21.4.0)
# Requirement already satisfied: iniconfig in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pytest->pendsim==1.0.4) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pytest->pendsim==1.0.4) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pytest->pendsim==1.0.4) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from pytest->pendsim==1.0.4) (2.0.1)
# Requirement already satisfied: joblib>=0.11 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->pendsim==1.0.4) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dcopp/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->pendsim==1.0.4) (2.2.0)

# %% [markdown]
# We import the simulation logic from `pendulum.sim`, any built-in controllers as well as the controller base class from `pendulum.controller`, and the visualizations are stored in `pendulum.viz`.

# %%
dt, t_final = 0.01, 5.0

pend = sim.Pendulum(
    2.0,  # Large mass, 2.0 kg
    1.0,  # Small mass, 1.0 kg
    2.0,  # length of arm, 2.0 meter
    initial_state=np.array([0.0, 0.0, 0.1, 0.0]),
)

# %% [markdown]
# Every simulation begins at t=0 and runs for some period of time, measured in seconds. Each simulation has a timestep, usually denoted `dt`,which tells us how often the controller's `policy` is implemented.
#
# A pendulum is created by instantiating a new `Pendulum` class. This class takes three arguments, M, m, and l. So here, we have created a cart with mass 2kg, a pendulum with mass 1kg, and an arm length 2 m. We also pass in an optional `initial_state` which sets ``[x=0, xdot=0, theta=0.1, thetadot=0]``. So, we start off slightly tipped over.

# %%
cont = controller.NoController()

# %% [markdown]
# We just set the controller to be a basic controller. It will read the state and will do nothing every timestep. We need to provide a controller every time we run the simulation, even if it does nothing like this one.

# %%
simu = sim.Simulation(dt, t_final, lambda t: 0)

# %% [markdown]
# We create a simulation, with timestep `dt`, final time `t_final`, and an external force function of `lambda t: 0`, which basically just returns 0 external force for every time value `t`.

# %%
results = simu.simulate(pend, cont)
# Out:
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 4544.18it/s]

# %% [markdown]
# Calling `simulate` on the simulation object actually runs the simulation. `simulate` takes 2 arguments, a pendulum object and a controller object. The results of the simulation are stored into a dataframe, results.

# %%
print(results.columns)
# Out:
# MultiIndex([(         'state',              'x'),
#             (         'state',             'xd'),
#             (         'state',              't'),
#             (         'state',             'td'),
#             (        'energy',        'kinetic'),
#             (        'energy',      'potential'),
#             (        'energy',          'total'),
#             (        'forces',         'forces'),
#             ('control action', 'control action'),
#             (        'forces',            'pRx'),
#             (        'forces',            'pRy'),
#             (        'forces',             'pG'),
#             (        'forces',            'cRy'),
#             (        'forces',            'cRx'),
#             (        'forces',             'cG'),
#             (        'forces',             'cN')],
#            )

# %% [markdown]
# So let's see what data we got back. Because there are 4 different states, we have a multi-index with two levels. This allows us to group quantities together to more easily slice and dice the results we get. Often, we see `x`, `xd`, `t`, `td` grouped together as subquantities, because they are our state vectors.

# %%
fig, ax = plt.subplots(nrows=4, sharex=True)
state_labels = ["x", "xd", "t", "td"]
for i, s in enumerate(state_labels):
    ax[i].plot(results[("state", s)], label="state")
ax[0].set_ylabel(r"$x$ [m]")
ax[1].set_ylabel(r"$\dot x$ [m/s]")
ax[2].set_ylabel(r"$\theta$ [rad]")
ax[3].set_ylabel(r"$\dot\theta$ [rad/s]")
ax[3].set_xlabel("Time [s]")
# Out:
# Text(0.5, 0, 'Time [s]')

# %% [markdown]
# We can see some results of the simulation. It looks like our positive initial $\theta$ value caused the pendulum to tip over and just about swing completely back up.

# %%
visu = viz.Visualizer(results, pend, dt=dt, speed=1)

# %% [markdown]
# We can confirm this by creating a vizualizer using the `Visualizer` class. We instantiate it with the same `pend` object, and the results from our simulation.

# %%
ani = visu.animate()

# %% [markdown]
# We can animate the figure by calling the `Visualizer`'s `animate` function. Importantly, we must bind the result of that function to a variable, `ani`, because the animation plays as long as that variable exists. If we just call `visu.animate()` without storing the result in a varialbe, the animation will only exist long enough to be created and then immediately destroyed.
#
# So, just bind your animations to variables.

# %% [markdown]
# In order to display properly in notebooks, it sometimes may be necessarily to convert the generated animation to an HTML5 video:

# %%
from IPython.display import HTML
HTML(ani.to_html5_video())
# Out:
# <video width="800" height="450" controls autoplay loop>
#   <source type="video/mp4" src="...
